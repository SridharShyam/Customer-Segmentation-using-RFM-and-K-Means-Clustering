# %%
import pandas as pd

data = pd.read_excel("/content/Online Retail.xlsx")
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...

# %%
data.tail(10)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541899    581587     22726       ALARM CLOCK BAKELIKE GREEN         4
# 541900    581587     22730       ALARM CLOCK BAKELIKE IVORY         4
# 541901    581587     22367  CHILDRENS APRON SPACEBOY DESIGN         8
# 541902    581587     22629              SPACEBOY LUNCH BOX         12
# 541903    581587     23256      CHILDRENS CUTLERY SPACEBOY          4
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541899 2011-12-09 12:50:00       3.75     12680.0  France
# 541900 2011-12-09 12:50:00       3.75     12680.0  France
# ...

# %%
data.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  541909.000000                         541909  541909.000000
# mean        9.552250  2011-07-04 13:34:57.156386048       4.611114
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-28 11:34:00       1.250000
# 50%         3.000000            2011-07-19 17:17:00       2.080000
# 75%        10.000000            2011-10-19 11:27:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       218.081158                            NaN      96.759853
#
#           CustomerID
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %%
data.describe(include='all')
# Out:
#         InvoiceNo StockCode                         Description  \
# count    541909.0    541909                              540455
# unique    25900.0      4070                                4223
# top      573585.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq       1114.0      2313                                2369
# mean          NaN       NaN                                 NaN
# min           NaN       NaN                                 NaN
# 25%           NaN       NaN                                 NaN
# 50%           NaN       NaN                                 NaN
# 75%           NaN       NaN                                 NaN
# max           NaN       NaN                                 NaN
# std           NaN       NaN                                 NaN
#
#              Quantity                    InvoiceDate      UnitPrice  \
# count   541909.000000                         541909  541909.000000
# ...

# %%
data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
data.shape
# Out:
# (541909, 8)

# %%
missing_percent = data.isnull().mean() * 100
print("Percentage of Missing Values:\n", missing_percent)

missing_rows_count = data.isnull().any(axis=1).sum()
print(f"Rows with missing values: {missing_rows_count}")

total_rows = len(data)
removal_percent = (missing_rows_count / total_rows) * 100
print(f"Percentage of rows to be removed: {removal_percent:.2f}%")

data_clean = data.dropna()

print(f"Original Dataset Size: {data.shape}")
print(f"Cleaned Dataset Size: {data_clean.shape}")
# Out:
# Percentage of Missing Values:
#  InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.268311
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     24.926694
# Country         0.000000
# dtype: float64
# Rows with missing values: 135080
# Percentage of rows to be removed: 24.93%
# Original Dataset Size: (541909, 8)
# Cleaned Dataset Size: (406829, 8)

# %%
Data=data.dropna(axis=0,how='any')

# %%
Data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
Data=Data[['CustomerID','InvoiceNo','InvoiceDate','Quantity','UnitPrice','Country']]

# %%
Data
# Out:
#         CustomerID InvoiceNo         InvoiceDate  Quantity  UnitPrice  \
# 0          17850.0    536365 2010-12-01 08:26:00         6       2.55
# 1          17850.0    536365 2010-12-01 08:26:00         6       3.39
# 2          17850.0    536365 2010-12-01 08:26:00         8       2.75
# 3          17850.0    536365 2010-12-01 08:26:00         6       3.39
# 4          17850.0    536365 2010-12-01 08:26:00         6       3.39
# ...            ...       ...                 ...       ...        ...
# 541904     12680.0    581587 2011-12-09 12:50:00        12       0.85
# 541905     12680.0    581587 2011-12-09 12:50:00         6       2.10
# 541906     12680.0    581587 2011-12-09 12:50:00         4       4.15
# 541907     12680.0    581587 2011-12-09 12:50:00         4       4.15
# 541908     12680.0    581587 2011-12-09 12:50:00         3       4.95
#
#                Country
# 0       United Kingdom
# 1       United Kingdom
# 2       United Kingdom
# 3       United Kingdom
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   CustomerID   406829 non-null  float64
#  1   InvoiceNo    406829 non-null  object
#  2   InvoiceDate  406829 non-null  datetime64[ns]
#  3   Quantity     406829 non-null  int64
#  4   UnitPrice    406829 non-null  float64
#  5   Country      406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 21.7+ MB

# %%
Data.describe()
# Out:
#           CustomerID                    InvoiceDate       Quantity  \
# count  406829.000000                         406829  406829.000000
# mean    15287.690570  2011-07-10 16:30:57.879207424      12.061303
# min     12346.000000            2010-12-01 08:26:00  -80995.000000
# 25%     13953.000000            2011-04-06 15:02:00       2.000000
# 50%     15152.000000            2011-07-31 11:48:00       5.000000
# 75%     16791.000000            2011-10-20 13:06:00      12.000000
# max     18287.000000            2011-12-09 12:50:00   80995.000000
# std      1713.600303                            NaN     248.693370
#
#            UnitPrice
# count  406829.000000
# mean        3.460471
# min         0.000000
# 25%         1.250000
# 50%         1.950000
# 75%         3.750000
# max     38970.000000
# std        69.315162

# %%
positives1=(Data['CustomerID']>0).all().all()
positives1
# Out:
# np.True_

# %%
positives2=(Data['Quantity']>0).all().all()
positives2
# Out:
# np.False_

# %%
Data = Data[Data['Quantity'] > 0]
Data
# Out:
#         CustomerID InvoiceNo         InvoiceDate  Quantity  UnitPrice  \
# 0          17850.0    536365 2010-12-01 08:26:00         6       2.55
# 1          17850.0    536365 2010-12-01 08:26:00         6       3.39
# 2          17850.0    536365 2010-12-01 08:26:00         8       2.75
# 3          17850.0    536365 2010-12-01 08:26:00         6       3.39
# 4          17850.0    536365 2010-12-01 08:26:00         6       3.39
# ...            ...       ...                 ...       ...        ...
# 541904     12680.0    581587 2011-12-09 12:50:00        12       0.85
# 541905     12680.0    581587 2011-12-09 12:50:00         6       2.10
# 541906     12680.0    581587 2011-12-09 12:50:00         4       4.15
# 541907     12680.0    581587 2011-12-09 12:50:00         4       4.15
# 541908     12680.0    581587 2011-12-09 12:50:00         3       4.95
#
#                Country
# 0       United Kingdom
# 1       United Kingdom
# 2       United Kingdom
# 3       United Kingdom
# ...

# %%
positives3=(Data['Quantity']>0).all().all()
positives3
# Out:
# np.True_

# %%
positives4=(Data['UnitPrice']>0).all().all()
positives4
# Out:
# np.False_

# %%
Data = Data[Data['UnitPrice'] > 0]
Data
# Out:
#         CustomerID InvoiceNo         InvoiceDate  Quantity  UnitPrice  \
# 0          17850.0    536365 2010-12-01 08:26:00         6       2.55
# 1          17850.0    536365 2010-12-01 08:26:00         6       3.39
# 2          17850.0    536365 2010-12-01 08:26:00         8       2.75
# 3          17850.0    536365 2010-12-01 08:26:00         6       3.39
# 4          17850.0    536365 2010-12-01 08:26:00         6       3.39
# ...            ...       ...                 ...       ...        ...
# 541904     12680.0    581587 2011-12-09 12:50:00        12       0.85
# 541905     12680.0    581587 2011-12-09 12:50:00         6       2.10
# 541906     12680.0    581587 2011-12-09 12:50:00         4       4.15
# 541907     12680.0    581587 2011-12-09 12:50:00         4       4.15
# 541908     12680.0    581587 2011-12-09 12:50:00         3       4.95
#
#                Country
# 0       United Kingdom
# 1       United Kingdom
# 2       United Kingdom
# 3       United Kingdom
# ...

# %%
positives5=(Data['UnitPrice']>0).all().all()
positives5
# Out:
# np.True_

# %%
Data['TotalSpend'] = Data['Quantity'] * Data['UnitPrice']
Data
# Out:
# <ipython-input-781-bc3a7db50e4f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['TotalSpend'] = Data['Quantity'] * Data['UnitPrice']
#         CustomerID InvoiceNo         InvoiceDate  Quantity  UnitPrice  \
# 0          17850.0    536365 2010-12-01 08:26:00         6       2.55
# 1          17850.0    536365 2010-12-01 08:26:00         6       3.39
# 2          17850.0    536365 2010-12-01 08:26:00         8       2.75
# 3          17850.0    536365 2010-12-01 08:26:00         6       3.39
# 4          17850.0    536365 2010-12-01 08:26:00         6       3.39
# ...            ...       ...                 ...       ...        ...
# 541904     12680.0    581587 2011-12-09 12:50:00        12       0.85
# ...

# %%
Data['InvoiceDate'] = pd.to_datetime(Data['InvoiceDate'], format='%d-%m-%Y %H:%M', errors='coerce')
# Out:
# <ipython-input-782-ca94e004d71e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['InvoiceDate'] = pd.to_datetime(Data['InvoiceDate'], format='%d-%m-%Y %H:%M', errors='coerce')

# %%
Data
# Out:
#         CustomerID InvoiceNo         InvoiceDate  Quantity  UnitPrice  \
# 0          17850.0    536365 2010-12-01 08:26:00         6       2.55
# 1          17850.0    536365 2010-12-01 08:26:00         6       3.39
# 2          17850.0    536365 2010-12-01 08:26:00         8       2.75
# 3          17850.0    536365 2010-12-01 08:26:00         6       3.39
# 4          17850.0    536365 2010-12-01 08:26:00         6       3.39
# ...            ...       ...                 ...       ...        ...
# 541904     12680.0    581587 2011-12-09 12:50:00        12       0.85
# 541905     12680.0    581587 2011-12-09 12:50:00         6       2.10
# 541906     12680.0    581587 2011-12-09 12:50:00         4       4.15
# 541907     12680.0    581587 2011-12-09 12:50:00         4       4.15
# 541908     12680.0    581587 2011-12-09 12:50:00         3       4.95
#
#                Country  TotalSpend
# 0       United Kingdom       15.30
# 1       United Kingdom       20.34
# ...

# %%
dup=Data.duplicated()
dup
# Out:
# 0         False
# 1         False
# 2         False
# 3          True
# 4          True
#           ...
# 541904    False
# 541905    False
# 541906     True
# 541907     True
# 541908    False
# Length: 397884, dtype: bool

# %%
Data.duplicated().sum()
# Out:
# np.int64(150457)

# %%
Data.drop_duplicates(inplace=True)
# Out:
# <ipython-input-786-4fcf340a7edf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data.drop_duplicates(inplace=True)

# %%
Data
# Out:
#         CustomerID InvoiceNo         InvoiceDate  Quantity  UnitPrice  \
# 0          17850.0    536365 2010-12-01 08:26:00         6       2.55
# 1          17850.0    536365 2010-12-01 08:26:00         6       3.39
# 2          17850.0    536365 2010-12-01 08:26:00         8       2.75
# 5          17850.0    536365 2010-12-01 08:26:00         2       7.65
# 6          17850.0    536365 2010-12-01 08:26:00         6       4.25
# ...            ...       ...                 ...       ...        ...
# 541901     12680.0    581587 2011-12-09 12:50:00         8       1.95
# 541903     12680.0    581587 2011-12-09 12:50:00         4       4.15
# 541904     12680.0    581587 2011-12-09 12:50:00        12       0.85
# 541905     12680.0    581587 2011-12-09 12:50:00         6       2.10
# 541908     12680.0    581587 2011-12-09 12:50:00         3       4.95
#
#                Country  TotalSpend
# 0       United Kingdom       15.30
# 1       United Kingdom       20.34
# ...

# %%
Data['CustomerID'].nunique()
# Out:
# 4338

# %%
Data['InvoiceNo'].nunique()
# Out:
# 18532

# %%
Data['UnitPrice'].nunique()
# Out:
# 440

# %%
Data['Country'].nunique()
# Out:
# 37

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Data['InvoiceDate'] = pd.to_datetime(Data['InvoiceDate'])  # Ensure datetime format
Data.set_index('InvoiceDate')['TotalSpend'].resample('M').sum().plot(title="Monthly Sales Trend")
plt.show()
# Out:
# <ipython-input-793-d7f2cdf756b9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['InvoiceDate'] = pd.to_datetime(Data['InvoiceDate'])  # Ensure datetime format
# <ipython-input-793-d7f2cdf756b9>:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   Data.set_index('InvoiceDate')['TotalSpend'].resample('M').sum().plot(title="Monthly Sales Trend")

# %%
customer_data = Data.groupby('CustomerID').agg({
    'InvoiceNo': 'nunique',  # Number of purchases
    'Quantity': 'sum',        # Total quantity bought
    'TotalSpend': 'sum'       # Total money spent
}).reset_index()

# %%
customer_data
# Out:
#       CustomerID  InvoiceNo  Quantity  TotalSpend
# 0        12346.0          1     74215    77183.60
# 1        12347.0          7      1716     3125.98
# 2        12348.0          4      1261     1399.80
# 3        12349.0          1       362     1209.49
# 4        12350.0          1       101      174.20
# ...          ...        ...       ...         ...
# 4333     18280.0          1        35      147.90
# 4334     18281.0          1        29       53.79
# 4335     18282.0          2       102      165.30
# 4336     18283.0         16       551      875.63
# 4337     18287.0          3      1046     1225.76
#
# [4338 rows x 4 columns]

# %%
reference_date = Data['InvoiceDate'].max()

rfm = Data.groupby('CustomerID').agg({
    'InvoiceDate': lambda x: (reference_date - x.max()).days,  # Recency: Days since last purchase
    'InvoiceNo': 'nunique',  # Frequency: Unique purchases
    'TotalSpend': 'sum'  # Monetary: Total money spent
}).reset_index()

rfm.columns = ['CustomerID', 'Recency', 'Frequency', 'Monetary']

rfm
# Out:
#       CustomerID  Recency  Frequency  Monetary
# 0        12346.0      325          1  77183.60
# 1        12347.0        1          7   3125.98
# 2        12348.0       74          4   1399.80
# 3        12349.0       18          1   1209.49
# 4        12350.0      309          1    174.20
# ...          ...      ...        ...       ...
# 4333     18280.0      277          1    147.90
# 4334     18281.0      180          1     53.79
# 4335     18282.0        7          2    165.30
# 4336     18283.0        3         16    875.63
# 4337     18287.0       42          3   1225.76
#
# [4338 rows x 4 columns]

# %%
rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4338 entries, 0 to 4337
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  4338 non-null   float64
#  1   Recency     4338 non-null   int64
#  2   Frequency   4338 non-null   int64
#  3   Monetary    4338 non-null   float64
# dtypes: float64(2), int64(2)
# memory usage: 135.7 KB

# %%
rfm.describe()
# Out:
#          CustomerID      Recency    Frequency       Monetary
# count   4338.000000  4338.000000  4338.000000    4338.000000
# mean   15300.408022    91.536422     4.272015    1533.853512
# std     1721.808492   100.014169     7.697998    6988.432429
# min    12346.000000     0.000000     1.000000       3.750000
# 25%    13813.250000    17.000000     1.000000     221.825000
# 50%    15299.500000    50.000000     2.000000     495.930000
# 75%    16778.750000   141.000000     5.000000    1188.825000
# max    18287.000000   373.000000   209.000000  202359.830000

# %%
posi1=(rfm['CustomerID']>0).all().all()
posi1
# Out:
# np.True_

# %%
posi2=(rfm['Frequency']>0).all().all()
posi2
# Out:
# np.True_

# %%
posi3=(rfm['Recency']>0).all().all()
posi3
# Out:
# np.False_

# %%
rfm=rfm[rfm['Recency']>0]
rfm
# Out:
#       CustomerID  Recency  Frequency  Monetary
# 0        12346.0      325          1  77183.60
# 1        12347.0        1          7   3125.98
# 2        12348.0       74          4   1399.80
# 3        12349.0       18          1   1209.49
# 4        12350.0      309          1    174.20
# ...          ...      ...        ...       ...
# 4333     18280.0      277          1    147.90
# 4334     18281.0      180          1     53.79
# 4335     18282.0        7          2    165.30
# 4336     18283.0        3         16    875.63
# 4337     18287.0       42          3   1225.76
#
# [4245 rows x 4 columns]

# %%
posi4=(rfm['Monetary']>0).all().all()
posi4
# Out:
# np.True_

# %%
rfm
# Out:
#       CustomerID  Recency  Frequency  Monetary
# 0        12346.0      325          1  77183.60
# 1        12347.0        1          7   3125.98
# 2        12348.0       74          4   1399.80
# 3        12349.0       18          1   1209.49
# 4        12350.0      309          1    174.20
# ...          ...      ...        ...       ...
# 4333     18280.0      277          1    147.90
# 4334     18281.0      180          1     53.79
# 4335     18282.0        7          2    165.30
# 4336     18283.0        3         16    875.63
# 4337     18287.0       42          3   1225.76
#
# [4245 rows x 4 columns]

# %%
rfm.describe()
# Out:
#          CustomerID      Recency    Frequency       Monetary
# count   4245.000000  4245.000000  4245.000000    4245.000000
# mean   15303.684099    93.541814     3.965371    1346.738915
# std     1720.436232   100.171836     5.772385    5626.719882
# min    12346.000000     1.000000     1.000000       3.750000
# 25%    13823.000000    18.000000     1.000000     217.280000
# 50%    15304.000000    51.000000     2.000000     484.010000
# 75%    16776.000000   146.000000     4.000000    1129.740000
# max    18287.000000   373.000000   124.000000  202359.830000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,5))
sns.histplot(rfm['Recency'],bins=20,kde=True,color='violet')
plt.title('Distribution of Recency')
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.histplot(rfm['Frequency'],bins=20,kde=True,color='indigo')
plt.title("Distribution of Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(rfm['Monetary'],bins=20,kde=True,color='blue')
plt.title("Distribution of Monetary")
plt.show()

# %%
rfm_means=rfm[['Recency', 'Frequency', 'Monetary']].mean()
plt.figure(figsize=(6,5))
rfm_means.plot(kind='bar', color=['#FF6F61', '#6B5B95', '#88B04B'])
plt.title('Average RFM Values')
plt.xlabel('RFM Metrics')
plt.ylabel('Average Value')
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.scatter(rfm['Recency'],rfm['Monetary'], alpha=0.5)
plt.title('Scatter Plot of Recency vs Monetary Value')
plt.xlabel('Days Since Last Purchase')
plt.ylabel('Total Spend')
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.scatter(rfm['Frequency'],rfm['Monetary'], alpha=0.5)
plt.title('Scatter Plot of Frequency vs Monetary Value')
plt.xlabel('Total no.of product purchased')
plt.ylabel('Total Spend')
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.violinplot(y=rfm['Recency'],color='chocolate')
plt.title("Recency Violin Plot")
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.violinplot(y=rfm['Frequency'],color='sienna')
plt.title("Recency Violin Plot")
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.violinplot(y=rfm['Monetary'],color='brown')
plt.title("Recency Violin Plot")
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.heatmap(rfm[['Recency', 'Frequency', 'Monetary']].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of RFM Metrics')
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.boxplot(y=rfm['Recency'],color='yellow')
plt.title("Recency Outliers")
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.boxplot(y=rfm['Frequency'],color='orange')
plt.title("Frequency Outliers")
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.boxplot(y=rfm['Monetary'],color='red')
plt.title('Monetary Outliers')
plt.show()

# %%
q1=rfm[['Recency', 'Frequency', 'Monetary']].quantile(0.25)
q2=rfm[['Recency', 'Frequency', 'Monetary']].quantile(0.50)
q3=rfm[['Recency', 'Frequency', 'Monetary']].quantile(0.75)
q4=rfm[['Recency', 'Frequency', 'Monetary']].quantile(1)

# %%
q1
# Out:
# Recency       18.00
# Frequency      1.00
# Monetary     217.28
# Name: 0.25, dtype: float64

# %%
q2
# Out:
# Recency       51.00
# Frequency      2.00
# Monetary     484.01
# Name: 0.5, dtype: float64

# %%
q3
# Out:
# Recency       146.00
# Frequency       4.00
# Monetary     1129.74
# Name: 0.75, dtype: float64

# %%
q4
# Out:
# Recency         373.00
# Frequency       124.00
# Monetary     202359.83
# Name: 1.0, dtype: float64

# %%
IQR=q3-q1
IQR
# Out:
# Recency      128.00
# Frequency      3.00
# Monetary     912.46
# dtype: float64

# %%
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR

# %%
lower_bound
# Out:
# Recency      -174.00
# Frequency      -3.50
# Monetary    -1151.41
# dtype: float64

# %%
upper_bound
# Out:
# Recency       338.00
# Frequency       8.50
# Monetary     2498.43
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

to_scale=rfm[['Recency', 'Frequency', 'Monetary']]
scaler=StandardScaler()
rfm_scaled=scaler.fit_transform(to_scale)

rfm_scaled=pd.DataFrame(rfm_scaled,columns=['Recency', 'Frequency', 'Monetary'])

rfm_scaled
# Out:
#        Recency  Frequency   Monetary
# 0     2.310884  -0.513777  13.479575
# 1    -0.923939   0.525777   0.316250
# 2    -0.195106   0.006000   0.009431
# 3    -0.754211  -0.513777  -0.024395
# 4     2.151139  -0.513777  -0.208412
# ...        ...        ...        ...
# 4240  1.831651  -0.513777  -0.213087
# 4241  0.863200  -0.513777  -0.229814
# 4242 -0.864035  -0.340518  -0.209994
# 4243 -0.903971   2.085108  -0.083737
# 4244 -0.514595  -0.167259  -0.021503
#
# [4245 rows x 3 columns]

# %%
from sklearn.cluster import KMeans

inertia = []
k_values = range(1, 11)

for k in k_values:
    k_means = KMeans(n_clusters=k, random_state=42)
    k_means.fit(rfm_scaled)
    inertia.append(k_means.inertia_)

plt.figure(figsize=(6, 5))
plt.plot(k_values, inertia, marker='o')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Inertia')
plt.title('Elbow Method to Determine Optimal K')
plt.show()

# %%
k_optimal = 4
k_means = KMeans(n_clusters=k_optimal, random_state=42)

rfm = rfm.copy()

rfm['Clusters'] = k_means.fit_predict(rfm_scaled)

cluster_summary = rfm.groupby('Clusters')[['Recency', 'Frequency', 'Monetary']].mean().round(4)

cluster_summary
# Out:
#            Recency  Frequency    Monetary
# Clusters
# 0          45.0170     3.2722    857.9078
# 1          27.5000    55.1875  67404.9200
# 2         248.2209     1.5365    345.4208
# 3          17.7037    16.5488   6080.1623

# %%
from sklearn.metrics import silhouette_score

score = silhouette_score(rfm_scaled, rfm['Clusters'])
print(f"Silhouette Score: {score:.3f}")
# Out:
# Silhouette Score: 0.592

# %%
from sklearn.metrics import davies_bouldin_score

db_score = davies_bouldin_score(rfm_scaled, rfm['Clusters'])
print(f"Davies-Bouldin Index: {db_score:.3f}")
# Out:
# Davies-Bouldin Index: 0.712

# %%
from sklearn.metrics import calinski_harabasz_score

ch_score = calinski_harabasz_score(rfm_scaled, rfm['Clusters'])
print(f"Calinski-Harabasz Score: {ch_score:.2f}")
# Out:
# Calinski-Harabasz Score: 3092.69

# %%
from sklearn.decomposition import PCA
import seaborn as sns
import matplotlib.pyplot as plt

pca = PCA(n_components=2)
rfm_pca = pca.fit_transform(rfm_scaled)

pca_df = pd.DataFrame(data=rfm_pca, columns=['PCA1', 'PCA2'])
pca_df['Cluster'] = rfm['Clusters'].values

plt.figure(figsize=(8, 6))
sns.scatterplot(data=pca_df, x='PCA1', y='PCA2', hue='Cluster', palette='coolwarm', s=60)
plt.title('Customer Segments based on KMeans Clustering (PCA Visualization)')
plt.xlabel('Spending-Recency Profile')
plt.ylabel('Frequency-Monetary Profile')
plt.legend(title='Cluster', loc='best')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

palette = sns.color_palette("Set2")

plt.figure(figsize=(6, 5))
sns.boxplot(data=rfm, x='Clusters', y='Recency', palette=palette)
plt.title('Recency Distribution by Customer Clusters', fontsize=14)
plt.xlabel('Customer Clusters')
plt.ylabel('Recency (days)')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-835-1aa833e34c6a>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=rfm, x='Clusters', y='Recency', palette=palette)
# <ipython-input-835-1aa833e34c6a>:7: UserWarning: The palette list has more values (8) than needed (4), which may not be intended.
#   sns.boxplot(data=rfm, x='Clusters', y='Recency', palette=palette)

# %%
plt.figure(figsize=(6, 5))
sns.boxplot(data=rfm, x='Clusters', y='Frequency', palette=palette)
plt.title('Frequency Distribution by Customer Clusters', fontsize=14)
plt.xlabel('Customer Clusters')
plt.ylabel('Purchase Frequency')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-836-d33d057f1913>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=rfm, x='Clusters', y='Frequency', palette=palette)
# <ipython-input-836-d33d057f1913>:2: UserWarning: The palette list has more values (8) than needed (4), which may not be intended.
#   sns.boxplot(data=rfm, x='Clusters', y='Frequency', palette=palette)

# %%
plt.figure(figsize=(6, 5))
sns.boxplot(data=rfm, x='Clusters', y='Monetary', palette=palette)
plt.title('Monetary Value Distribution by Customer Clusters', fontsize=14)
plt.xlabel('Customer Clusters')
plt.ylabel('Monetary Value ($)')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-837-e4b551348a7d>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=rfm, x='Clusters', y='Monetary', palette=palette)
# <ipython-input-837-e4b551348a7d>:2: UserWarning: The palette list has more values (8) than needed (4), which may not be intended.
#   sns.boxplot(data=rfm, x='Clusters', y='Monetary', palette=palette)

# %%
rfm_scaled['CustomerID'] = rfm['CustomerID'].values

# %%
import pandas as pd

# Make sure rfm_scaled is a DataFrame with CustomerID included
rfm = rfm_scaled.copy()

# Use rank to simulate RFM scoring
rfm['R_Score'] = rfm['Recency'].rank(pct=True)
rfm['F_Score'] = rfm['Frequency'].rank(pct=True)
rfm['M_Score'] = rfm['Monetary'].rank(pct=True)

# Convert to 1–5 score buckets
rfm['R_Score'] = pd.cut(rfm['R_Score'], bins=5, labels=[5, 4, 3, 2, 1]).astype(int)
rfm['F_Score'] = pd.cut(rfm['F_Score'], bins=5, labels=[1, 2, 3, 4, 5]).astype(int)
rfm['M_Score'] = pd.cut(rfm['M_Score'], bins=5, labels=[1, 2, 3, 4, 5]).astype(int)

# Combine scores
rfm['RFM_Segment'] = rfm['R_Score'].astype(str) + rfm['F_Score'].astype(str) + rfm['M_Score'].astype(str)
rfm['RFM_Score'] = rfm[['R_Score', 'F_Score', 'M_Score']].sum(axis=1)

# Segment customers
def rfm_segment(row):
    r, f, m = row['R_Score'], row['F_Score'], row['M_Score']
    if r >= 4 and f >= 4 and m >= 4:
        return 'Loyal Customers'
    elif r >= 4 and f >= 4 and m < 4:
        return 'Potential Loyalists'
    elif r >= 4 and f < 4 and m >= 4:
        return 'Big Ticket Shoppers'
    elif r >= 4 and f < 4 and m < 4:
        return 'New or Inactive Customers'
    elif r < 4 and f >= 4 and m >= 4:
        return 'At-Risk High-Value Customers'
    elif r < 4 and f >= 4 and m < 4:
        return 'Frequent Low Spenders'
    elif r < 4 and f < 4 and m >= 4:
        return 'At-Risk Big Spenders'
    else:
        return 'Lost or Dormant Customers'

rfm['RFM_Category'] = rfm.apply(rfm_segment, axis=1)

# Display result with CustomerID and other columns
rfm[['CustomerID', 'Recency', 'Frequency', 'Monetary', 'R_Score', 'F_Score', 'M_Score', 'RFM_Category']]
# Out:
#       CustomerID   Recency  Frequency   Monetary  R_Score  F_Score  M_Score  \
# 0        12346.0  2.310884  -0.513777  13.479575        1        1        5
# 1        12347.0 -0.923939   0.525777   0.316250        5        5        5
# 2        12348.0 -0.195106   0.006000   0.009431        2        4        4
# 3        12349.0 -0.754211  -0.513777  -0.024395        4        1        4
# 4        12350.0  2.151139  -0.513777  -0.208412        1        1        1
# ...          ...       ...        ...        ...      ...      ...      ...
# 4240     18280.0  1.831651  -0.513777  -0.213087        1        1        1
# 4241     18281.0  0.863200  -0.513777  -0.229814        2        1        1
# 4242     18282.0 -0.864035  -0.340518  -0.209994        5        2        1
# 4243     18283.0 -0.903971   2.085108  -0.083737        5        5        4
# 4244     18287.0 -0.514595  -0.167259  -0.021503        3        3        4
#
#                       RFM_Category
# ...

# %%
import matplotlib.pyplot as plt

segment_counts = rfm['RFM_Category'].value_counts()

plt.figure(figsize=(10, 6))
bars = plt.barh(segment_counts.index, segment_counts.values, color='#00bfff', edgecolor='black')

plt.title('Customer Segment Distribution', fontsize=16, weight='bold')
plt.xlabel('Number of Customers', fontsize=12)
plt.ylabel('Customer Segment', fontsize=12)

for bar in bars:
    width = bar.get_width()
    plt.text(width + 1, bar.get_y() + bar.get_height()/2,
             f'{int(width)}', va='center', fontsize=10)

plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Print table header
print(f"{'CustomerID':<12}{'Recency':<10}{'Frequency':<10}{'Monetary':<12}{'RFM_Category'}")
print("-" * 60)

# Print each row as a table row
for index, row in rfm.iterrows():
    print(f"{row['CustomerID']:<12}{row['Recency']:<10}{row['Frequency']:<10}{row['Monetary']:<12.2f}{row['RFM_Category']}")
# Out:
# CustomerID  Recency   Frequency Monetary    RFM_Category
# ------------------------------------------------------------
# 12346.0     2.3108836005743014-0.513777278069818813.48       At-Risk Big Spenders
# 12347.0     -0.92393949727197730.52577684271491940.32        Loyal Customers
# 12348.0     -0.19510589806587130.0059997823225503260.01        At-Risk High-Value Customers
# 12349.0     -0.754211124854117-0.5137772780698188-0.02       Big Ticket Shoppers
# 12350.0     2.151139250063374-0.5137772780698188-0.21       Lost or Dormant Customers
# 12352.0     -0.58448275243625670.69903586284570910.15        At-Risk High-Value Customers
# 12353.0     1.0928329279284803-0.5137772780698188-0.22       Lost or Dormant Customers
# 12354.0     1.3723855413226032-0.5137772780698188-0.14       Lost or Dormant Customers
# 12355.0     1.19267314699781-0.5137772780698188-0.17       Lost or Dormant Customers
# 12356.0     -0.7142750372263852-0.167259237808239370.16        Big Ticket Shoppers
# ...

# %%
from tabulate import tabulate

# Convert DataFrame to a formatted table string
table = tabulate(rfm, headers='keys', tablefmt='pretty')
print(table)
# Out:
# +------+-----------------------+----------------------+-------------------------+------------+---------+---------+---------+-------------+-----------+------------------------------+
# |      |        Recency        |      Frequency       |        Monetary         | CustomerID | R_Score | F_Score | M_Score | RFM_Segment | RFM_Score |         RFM_Category         |
# +------+-----------------------+----------------------+-------------------------+------------+---------+---------+---------+-------------+-----------+------------------------------+
# |  0   |  2.3108836005743014   | -0.5137772780698188  |    13.47957544543277    |  12346.0   |    1    |    1    |    5    |     115     |     7     |     At-Risk Big Spenders     |
# |  1   |  -0.9239394972719773  |  0.5257768427149194  |   0.31625009392902687   |  12347.0   |    5    |    5    |    5    |     555     |    15     |       Loyal Customers        |
# ...
